# %%
from weather_anamoly.utils import ImportCoordinates, ImportData

# %%
coordinates = ImportCoordinates()
latitude, longitude = coordinates.Fetch_coordinates(city="pamarru")
data_frame = ImportData()
start_date = '2024-01-01'
end_date = '2024-01-31'
df = data_frame.extract(start_date, end_date, latitude, longitude)
df
# Out:
#                            temperature   humidity     pressure
# date
# 2023-12-31 18:30:00+00:00    21.299999  88.378586  1013.887695
# 2023-12-31 19:30:00+00:00    20.950001  91.428093  1013.486572
# 2023-12-31 20:30:00+00:00    20.549999  93.707344  1013.085327
# 2023-12-31 21:30:00+00:00    20.350000  92.538033  1012.684875
# 2023-12-31 22:30:00+00:00    20.100000  92.813667  1012.883301
# ...                                ...        ...          ...
# 2024-01-31 13:30:00+00:00    24.850000  79.936127  1013.205383
# 2024-01-31 14:30:00+00:00    24.600000  81.388367  1013.803406
# 2024-01-31 15:30:00+00:00    24.100000  84.379196  1014.200562
# 2024-01-31 16:30:00+00:00    23.700001  86.168190  1014.398315
# 2024-01-31 17:30:00+00:00    23.100000  89.071434  1014.395569
#
# [744 rows x 3 columns]
