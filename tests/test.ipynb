# %%
from weather_anamoly.utils import ImportData

# %%
data_import = ImportData()
start_date = "2023-01-01"
end_date = "2023-12-31"
# We could use geospace api to get lattitudes and logitudes
latitude = 90.0000
longitude = 90.0000
data_import.extract(start_date=start_date, end_date=end_date, latitude=latitude, longitude=longitude)

# %%
df = data_import.dataframe

# %%
# Out:
# temperature    0
# humidity       0
# pressure       0
# dtype: int64
