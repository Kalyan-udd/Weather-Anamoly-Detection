# %%
from weather_anamoly.utils import ImportData, ImportCoordinates

# %%
coordinates = ImportCoordinates()
data = ImportData()

# %%
st = "2016-01-01"
end = "2024-01-01"

# %%
latitude, longitude = coordinates.Fetch_coordinates("Kolkata")
df = data.extract(st, end, latitude, longitude)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 70152 entries, 2015-12-31 18:30:00+00:00 to 2024-01-01 17:30:00+00:00
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   temperature  70152 non-null  float32
#  1   humidity     70152 non-null  float32
#  2   pressure     70152 non-null  float32
# dtypes: float32(3)
# memory usage: 1.3 MB

# %%
df.describe()
# Out:
#         temperature      humidity      pressure
# count  70152.000000  70152.000000  70152.000000
# mean      26.071316     77.293365   1006.544617
# std        5.029720     16.826151      6.043047
# min        8.750000     11.436662    961.587524
# 25%       23.450001     67.934885   1001.765289
# 50%       26.950001     82.079865   1006.630920
# 75%       29.250000     90.648941   1011.620117
# max       42.150002    100.000000   1021.179077
