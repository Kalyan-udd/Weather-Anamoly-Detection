# %%
import pandas as pd

# %%
df_Delhi = pd.read_csv("data/Delhi_training_data.csv", parse_dates=['date'])
df_Chennai = pd.read_csv("data/Chennai_training_data.csv", parse_dates=['date'])
df_Leh = pd.read_csv("data/Leh_training_data.csv", parse_dates=['date'])
df_Jaisalmer = pd.read_csv("data/Jaisalmer_training_data.csv", parse_dates=['date'])
df_Kolkata = pd.read_csv("data/Kolkata_training_data.csv", parse_dates=['date'])
df_Shimla = pd.read_csv("data/Shimla_training_data.csv", parse_dates=['date'])
df_Guwahati = pd.read_csv("data/Guwahati_training_data.csv", parse_dates=['date'])
df_Bengaluru = pd.read_csv("data/Bengaluru_training_data.csv", parse_dates=['date'])
df_Visakhapatnam = pd.read_csv("data/Visakhapatnam_training_data.csv", parse_dates=['date'])

# %%
df_training['label'].value_counts()
# Out:
# label
# genuine    719334
# fault       66996
# frozen       2142
# spike         522
# Name: count, dtype: int64

# %%
df_training.to_csv("data/final_training_data.csv")

# %%
df_Delhi = pd.read_csv("data/Delhi_testing_data.csv", parse_dates=['date'])
df_Chennai = pd.read_csv("data/Chennai_testing_data.csv", parse_dates=['date'])
df_Leh = pd.read_csv("data/Leh_testing_data.csv", parse_dates=['date'])
df_Jaisalmer = pd.read_csv("data/Jaisalmer_testing_data.csv", parse_dates=['date'])
df_Kolkata = pd.read_csv("data/Kolkata_testing_data.csv", parse_dates=['date'])
df_Shimla = pd.read_csv("data/Shimla_testing_data.csv", parse_dates=['date'])
df_Guwahati = pd.read_csv("data/Guwahati_testing_data.csv", parse_dates=['date'])
df_Bengaluru = pd.read_csv("data/Bengaluru_testing_data.csv", parse_dates=['date'])
df_Visakhapatnam = pd.read_csv("data/Visakhapatnam_testing_data.csv", parse_dates=['date'])

# %%
df_testing = pd.concat([df_Delhi, df_Chennai, df_Leh,df_Jaisalmer,df_Kolkata, df_Shimla,df_Guwahati, df_Bengaluru, df_Visakhapatnam], ignore_index=True)

# %%
df_testing.to_csv("data/final_testing_data.csv")
