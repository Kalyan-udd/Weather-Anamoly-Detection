# %%
import pandas as pd

# %%
df = pd.read_csv("data/anomaly_labelled_data.csv", parse_dates=['date']).set_index("date")

# %%
df.columns
# Out:
# Index(['temperature', 'humidity', 'pressure', 'label', 'cos_hour', 'sin_hour',
#        'cos_month', 'sin_month', 'temp_gradient', 'pressure_gradient',
#        'humidity_gradient'],
#       dtype='str')

# %%
df.describe()
# Out:
#          temperature      humidity      pressure      cos_hour      sin_hour  \
# count   69626.000000  69591.000000  69705.000000  7.010300e+04  7.010300e+04
# mean     -946.260148   -396.585678    973.982685 -5.646850e-17  1.426472e-05
# std     11207.558364   3164.239066    245.471357  7.071169e-01  7.071068e-01
# min   -151533.482206 -42892.424917  -2115.908632 -1.000000e+00 -1.000000e+00
# 25%        23.161001     63.588127   1001.061650 -7.071068e-01 -7.071068e-01
# 50%        27.000000     80.768135   1006.038450  6.123234e-17  1.224647e-16
# 75%        29.700000     90.461195   1011.415830  7.071068e-01  7.071068e-01
# max     23334.266533   1495.519715   1143.942964  1.000000e+00  1.000000e+00
#
#           cos_month     sin_month  temp_gradient  pressure_gradient  \
# count  7.010300e+04  7.010300e+04   69462.000000       69580.000000
# mean  -2.349848e-03 -4.921876e-03       0.025342          -0.000466
# std    7.083601e-01  7.058403e-01     582.356155          16.662955
# ...
