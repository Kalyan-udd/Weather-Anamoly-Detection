# %%
from weather_anamoly.logger import logger

# %%
logger.info("hello this is the logger test message")
# Out:
# [2026-09-04 19:34:44]:[1]:[3948457850.py]:[3948457850]:message: hello this is the logger test message
